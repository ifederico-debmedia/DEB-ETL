# %%
#### este script extrae todos los contacts, companies y deals de hubspot y sus respectivas tablas de relaciones
#### en total se exportan 6 tablas a la base de datos postgre
#### 
#### table_index = {
####    hs_contacts
####    hs_contacts_to_deals
####    hs_contacts_to_companies
####    hs_companies
####    hs_companies_to_deals
####    hs_deals 
#### }

import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, types
from sqlalchemy.pool import NullPool
from hubspot.crm.contacts import SimplePublicObjectInput, ApiException
from hubspot.auth.oauth import ApiException
from validate_email import validate_email
import hubspot
import os
from dotenv import load_dotenv

load_dotenv()
DATABASE_CONNECTION_URI = os.environ["DB_URL"]
ACCESS_TOKEN = os.environ["ACCESS_TOKEN"]
client_id = os.environ["CLIENT_ID"]
client_secret = os.environ["CLIENT_SECRET"]

# create a connection to the database
engine = create_engine(DATABASE_CONNECTION_URI)

class HubspotAPI:
    def __init__(self):
        # API KEY
        self.access_token = ACCESS_TOKEN
        self.client = hubspot.Client.create(access_token = self.access_token)
        self.max_results = 1000000

    def raw_export_contacts(self, properties_dict):
        # Assistant Variables
        results = []
        after = 0
        
        while str(after).isnumeric() and len(results) < self.max_results:
            try:
                api_response = self.client.crm.contacts.basic_api.get_page(
                    limit=100,
                    after=after,
                    properties=list(properties_dict.keys()),
                    associations=["deals", "companies"],
                    archived=False,
                )
                api_response = api_response.to_dict()
                results.extend(api_response['results'])
                print("Hubspot Contacts Export has gathered " + str(len(results)) + " Contacts")
                msg1 = "Hubspot Contacts Export has gathered " + str(len(results)) + " Contacts"
                try:
                    after = api_response['paging']['next']['after']
                except:
                    after = api_response['paging']
            except ApiException as e:
                print("Exception when calling basic_api->get_page: %s\n" % e)
                msg1 = "Exception when calling basic_api->get_page: %s\n"
        property_results = []
        for result in results:
            property_results.append(result["properties"])
        df = pd.DataFrame(property_results)

        # Dictionary to map old column names to new column names
        column_mapping = {
            'hs_object_id': 'contact_id',
            'lastmodifieddate': 'last_modified',
            'hs_email_domain': 'email_domain',
            'hs_lead_status': 'lead_status',
            'hubspot_owner_id': 'owner_id',
            'hubspot_owner_assigneddate': 'owner_assigneddate',
            'prospecto_de_inbound': 'procedencia_de_lead',
            # Add more mappings as needed
        }

        # Use the rename() method to rename columns
        df.rename(columns=column_mapping, inplace=True)

        # Reorder columns for better read
        df = df[[
            'createdate',
            'contact_id',
            'email',
            'firstname',
            'lastname',
            'lead_status',
            'country',
            'region',
            'owner_id',
            'owner_assigneddate',
            'procedencia_de_lead',
            'canal_de_entrada',
            'company',
            'industry',
            'jobtitle',
            'email_domain',
            'last_modified',
            'num_associated_deals',
            'lifecyclestage',
            'hs_object_source_label',
            'hs_predictivescoringtier',
            'hs_marketable_status',
            'hs_analytics_source',
            'hs_analytics_source_data_1',
            'hs_analytics_source_data_2',
            'hs_latest_source',
            'hs_latest_source_data_1',
            'hs_latest_source_data_2',
            'hs_latest_source_timestamp',
            'recent_deal_amount',
            'num_notes',
            'num_contacted_notes',
            'notes_last_contacted',
        ]]

        try:
            df.to_sql('hs_contacts', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_contacts se actualizó correctamente en la base de datos.")
            msg2 = "La tabla hs_contacts se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg2 = f"Error al intentar escribir en la base de datos: {str(e)}"
        assoc_results = []
        itterator = results.copy()
        for result in itterator:
            try:
                lists_to_append = result["associations"]["deals"]["results"]
                to_append = []
                for i in lists_to_append:
                    dict_to_append = {}
                    dict_to_append["contact_id"] = result["id"]
                    dict_to_append["deal_id"] = i["id"]
                    to_append.append(dict_to_append)
                assoc_results.append(to_append)
            except:
                assoc_results.append([{"contact_id": result["id"], "deal_id": None}])
        contacts_id = []
        deal_id = []
        for index, item in enumerate(assoc_results):
            i = 0
            for a, b in item:
                contacts_id.append(item[i][a])
                deal_id.append(item[i][b])
                i += 1
        df = pd.DataFrame({"contact_id": contacts_id, "deals_id": deal_id})

        try:
            df.to_sql('hs_contacts_to_deals', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_contacts_to_deals se actualizó correctamente en la base de datos.")
            msg3 = "La tabla hs_contacts_to_deals se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg3 = f"Error al intentar escribir en la base de datos: {str(e)}"
        assoc_results = []
        for result in itterator:
            try:
                lists_to_append = result["associations"]["companies"]["results"]
                to_append = []
                for i in lists_to_append:
                    dict_to_append = {}
                    dict_to_append["contact_id"] = result["id"]
                    dict_to_append["company_id"] = i["id"]
                    to_append.append(dict_to_append)
                assoc_results.append(to_append)
            except Exception as e:
                assoc_results.append([{"contact_id": result["id"], "company_id": None}])
        contacts_id = []
        companies_id = []
        for index, item in enumerate(assoc_results):
            i = 0
            for a, b in item:
                contacts_id.append(item[i][a])
                companies_id.append(item[i][b])
                i += 1
        df = pd.DataFrame({"contact_id": contacts_id, "company_id": companies_id})

        try:
            df.to_sql('hs_contacts_to_companies', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_contacts_to_companies se actualizó correctamente en la base de datos.")
            msg4 = "La tabla hs_contacts_to_companies se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg4 = f"Error al intentar escribir en la base de datos: {str(e)}"

        return msg1, msg2, msg3, msg4
    
    def raw_export_companies(self, properties_dict):
        # Parameters
        results = []
        after_results = []
        previous_after = None
        after = 0

        while str(after).isnumeric():
            try:
                api_response = self.client.crm.companies.basic_api.get_page(
                    limit=100,
                    after=after,
                    properties=list(properties_dict.keys()),
                    associations=["deals"],
                    archived=False,
                )
                api_response = api_response.to_dict()
                results.extend(api_response['results'])
                print("Hubspot Companies Export has gathered " + str(len(results)) + " Companies")
                msg5 = "Hubspot Companies Export has gathered " + str(len(results)) + " Companies"
                try:
                    after = api_response['paging']['next']['after']
                except:
                    after = api_response['paging']
            except ApiException as e:
                print("Exception when calling basic_api->get_page: %s\n" % e)
                msg5 = "Exception when calling basic_api->get_page: %s\n"
        property_results = []
        for result in results:
            property_results.append(result["properties"])
        df = pd.DataFrame(property_results)

        # Dictionary to map old column names to new column names
        column_mapping = {
            'hs_object_id': 'company_id',
            'hs_lastmodifieddate': 'last_modified',
            # Add more mappings as needed
        }

        # Use the rename() method to rename columns
        df.rename(columns=column_mapping, inplace=True)

        # Reorder columns for better read
        df = df[[
            'createdate',
            'company_id',
            'name',
            'domain',
            'last_modified',
        ]]

        try:
            df.to_sql('hs_companies', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_companies se actualizó correctamente en la base de datos.")
            msg6 = "La tabla hs_companies se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg6 = f"Error al intentar escribir en la base de datos: {str(e)}"
        assoc_results = []
        itterator = results.copy()
        for result in itterator:
            if result["associations"] is not None:
                lists_to_append = result["associations"]["deals"]["results"]
                to_append = []
                for i in lists_to_append:
                    dict_to_append = {}
                    dict_to_append["company_id"] = result["id"]
                    dict_to_append["deal_id"] = i["id"]
                    to_append.append(dict_to_append)
                assoc_results.append(to_append)
            else:
                assoc_results.append([{"company_id": result["id"], "deal_id": None}])
        company_id = []
        deal_id = []
        for index, item in enumerate(assoc_results):
            i = 0
            for a, b in item:
                company_id.append(item[i][a])
                deal_id.append(item[i][b])
                i += 1
        df = pd.DataFrame({"company_id": company_id, "deals_id": deal_id})

        try:
            df.to_sql('hs_companies_to_deals', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_companies_to_deals se actualizó correctamente en la base de datos.")
            msg7 = "La tabla hs_companies_to_deals se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg7 = f"Error al intentar escribir en la base de datos: {str(e)}"

        return msg5, msg6, msg7

    def raw_export_deals(self, properties_dict):
        # Assistant Variables
        results = []
        after_results = []
        previous_after = None
        after = 0
        while str(after).isnumeric():
            try:
                api_response = self.client.crm.deals.basic_api.get_page(
                    limit=100,
                    after=after,
                    properties=list(properties_dict.keys()),
                    archived=False,
                )
                api_response = api_response.to_dict()
                results.extend(api_response['results'])
                print("Hubspot Deals Export has gathered " + str(len(results)) + " Deals")
                msg8 = "Hubspot Deals Export has gathered " + str(len(results)) + " Deals"
                try:
                    after = api_response['paging']['next']['after']
                except:
                    after = api_response['paging']
            except ApiException as e:
                print("Exception when calling basic_api->get_page: %s\n" % e)
                msg8 = "Exception when calling basic_api->get_page: %s\n"
        property_results = []
        for result in results:
            property_results.append(result["properties"])
        df = pd.DataFrame(property_results)

        # Dictionary to map old column names to new column names
        column_mapping = {
            'associated_company_proxy': 'associated_company',
            'associated_contact_proxy': 'associated_contact',
            'canal_de_representaci_n': 'canal_de_representacion',
            'hs_lastmodifieddate': 'last_modified',
            'hs_object_id': 'deal_id',
            'hubspot_owner_assigneddate': 'owner_assigneddate',
            'hubspot_owner_id': 'owner_id',
            'pa_s': 'pais',
            'procedencia': 'procedencia_del_lead',
            'hs_projected_amount': 'amount_weighted'
     
            # Add more mappings as needed
        }

        # Use the rename() method to rename columns
        df.rename(columns=column_mapping, inplace=True)

        # Define diccionarios de reemplazo para columnas específicas
        reemplazo_dealstage = {
            "5101741": 'Identificación de Oportunidad (Ventas)',
            "d85ad2ee-ad84-48f3-a4e6-3c2752733963": 'Primer Contacto 10% (Ventas)',
            "750846": 'Demo Realizada 15% (Ventas)',
            "eb078c2a-ae3e-411a-9ce6-b8e5ca06dcd5": 'Presupuesto Enviado 20% (Ventas)',
            "d5608044-cac5-4e0c-9838-755be8adf652": 'Opt Avanzada / En Piloto 50% (Ventas)',
            "afcc2b30-8757-4d7e-923d-053d7db0205c": 'OC en Proceso / Cercano a Cierre 90% (Ventas)',
            "3d0d99a8-5791-421b-a1e5-6234c0844b65": 'Deal Won (Ventas)',
            "03a76306-0231-417d-9223-5bd0b12f63d5": 'Deal Lost (Ventas)',
            "7356165": 'Oportunidad de Baja (Ventas)',
            "1005088": 'Partners potenciales (Partners)',
            "2ad1f599-a06f-4456-bea4-e28739d0c6fb": 'Partner confirmado (NDA firmado) - Coordinar Onboarding (Partners)',
            "17487102": 'Capacitación comercial coordinada (Partners)',
            "2014582": 'Capacitación técnica coordinada (Partners)',
            "1611634": 'Capacitación comercial y técnica coordinada (Partners)',
            "32753101-a1a6-4c44-a789-82576c7b1505": 'Partner certificado - VAR (Partners)',
            "7025326": 'Partner certificado - Referral (Partners)',
            "2491428": 'Canales en Pausa (Partners)',
            "ff4aae15-0c00-4fa8-a677-39b35df7924f": 'No hay interés/No califica (Partners)',
            "cf839eef-4bbd-4368-804d-6cf60dabc03c": 'Contactos Identficados (Prospección)',
            "d9852484-edc7-4623-9cec-6a1639cff93f": 'Secuencia Enviada (Prospección)',
            "cd642987-1f60-48d1-9d83-4042e15d4be8": 'En Seguimiento / No Contesta (Prospección)',
            "33ba8152-823d-49ff-abfc-cfb9951374f3": 'Agendamiento de Reunión (Prospección)',
            "45411143": 'Prospección Exitosa (Prospección)',
            "583eddf6-eeaa-418d-91d0-8de9e28a2ec3": 'No califica (Prospección)',
            "201584": 'Potentially Good Fit - Sin contacto previo (Investor Pipeline)',
            "201583": 'Exploratory meeting (Investor Pipeline)',
            "8b586784-2f37-4604-89bd-36d088131e4c": 'Potencial interest in following (Investor Pipeline)',
            "bbbfa8fe-eea1-4d0a-8c15-3b322e777348": 'Potencial lead Investor (Investor Pipeline)',
            "493985da-75dc-4e5d-b103-f7be26d8cdf7": 'Due dilligence (Investor Pipeline)',
            "92c9806c-f2b2-40bc-9e08-2e50738b4050": 'No fit (Investor Pipeline)',
            "839d6147-109d-4a3e-853b-25ecd3c9124e": 'Stand by (Investor Pipeline)',
            "23780789": 'Clientes (Customer Success & Upsell)',
            "93563059": 'Reunion 1  (Customer Success & Upsell)',
            "17681683": 'Reunion 2 (Customer Success & Upsell)',
            "17681685": 'Reunion 3 (Customer Success & Upsell)',
            "138434867": 'En Capacitacion (Customer Success & Upsell)',
            "138434869": 'Upsell (Customer Success & Upsell)',
            "138434868": 'Fin del ciclo (Customer Success & Upsell)',
            "22687028": 'Derivado a Soporte (Customer Success & Upsell)',
            "17681687": 'Derivado a Comercial (Customer Success & Upsell)',
            "17681688": 'Derivado a Renovacion (Customer Success & Upsell)',
            "29561767": 'Sin Respuesta (Customer Success & Upsell)'
        }
        reemplazo_pipeline = {
            "7742d15e-56ae-4415-9c86-567ad766837a": 'Ventas',
            "820bd061-2228-4455-a379-4bf409d4554a": 'Partners',
            "1e666b90-c872-4a63-a4c1-1bce1dc79947": 'Prospección',
            "b1830386-2a88-458f-9cb4-71511efaaf87": 'Investor Pipeline',
            "5667166": 'Customer Success & Upsell'
        }
        reemplazo_deal_owner = {
            "7288359": 'Juan Martín Balan',
            "7332199": 'Nicolas Demner',
            "7857377": 'Martin Matias Fernandez Canto',
            "9194130": 'Joaquin Zoilo',
            "9430040": 'Gustavo Lauria',
            "30126325": 'Ventas Debmedia',
            "34868053": 'Matías Restahinoch',
            "38062801": 'Agustin Gelman',
            "38276053": 'Agustina Arroyo',
            "38627077": 'Tomas Noya',
            "55049136": 'Matias Pumo',
            "55049155": 'Camilo Varacalli',
            "56630584": 'Nicolas Menzaghi',
            "101057642": 'Roswel Amador',
            "112117634": 'Camila Acosta',
            "121481834": 'Soporte Debmedia',
            "246829367": 'Rafael Mattos',
            "312155919": 'Mariano Ahualli',
            "326472108": 'Lucía Imperiali',
            "366806335": 'Jaime Rodriguez',
            "396946262": 'valentina mineo',
            "399508303": 'Mateo Scapoli',
            "546914565": 'Iván Federico',
            "584399104": 'Aaron Escamilla',
            "597453098": 'Agustín Dimaio',
            "613110176": 'Pablo Prez',
            "653869216": 'Juan Lissarrague',
            "679733780": 'Agustina Coronel',
            "8231273": 'deactivated user',
            "24586352": 'deactivated user',
            "14224485": 'deactivated user'
        }
        # Agrega más diccionarios según tus necesidades

        # Realiza el reemplazo en las columnas específicas
        df['dealstage'] = df['dealstage'].replace(reemplazo_dealstage)
        df['pipeline'] = df['pipeline'].replace(reemplazo_pipeline)
        df['owner_id'] = df['owner_id'].replace(reemplazo_deal_owner)

        # Diccionario de países y regiones comerciales
        diccionario_region_comercial = {
            'Argentina': 'Región 1 - AR, BO, PY, UR',
            'Bolivia': 'Región 1 - AR, BO, PY, UR',
            'Paraguay': 'Región 1 - AR, BO, PY, UR',
            'Uruguay': 'Región 1 - AR, BO, PY, UR',
            'Chile': 'Región 2 - CL, PE',
            'Perú': 'Región 2 - CL, PE',
            'Peru': 'Región 2 - CL, PE',
            'Colombia': 'Región 3 - CO, EC',
            'Ecuador': 'Región 3 - CO, EC',
            'México': 'Región 4 - MX',
            'Mexico': 'Región 4 - MX',
            'Costa Rica': 'Región 5 - Centroamérica',
            'Guatemala': 'Región 5 - Centroamérica',
            'Honduras': 'Región 5 - Centroamérica',
            'República Dominicana': 'Región 5 - Centroamérica',
            'Republica Dominicana': 'Región 5 - Centroamérica',
            'Guatemala': 'Región 5 - Centroamérica',
            'Puerto Rico': 'Región 5 - Centroamérica',
            'Nicaragua': 'Región 5 - Centroamérica',
            'Brasil': 'Región 6 - BR',
            'España': 'Región 7 - Europa',
            # Agrega más países según sea necesario
        }

        # Función para mapear la región comercial evitando asignar 'Otra Región' cuando el país es nulo
        def obtener_region_comercial(pais):
            if pais is not None and pais in diccionario_region_comercial:
                return diccionario_region_comercial[pais]
            else:
                return None  # O puedes devolver algún valor predeterminado según tus necesidades

        # Aplicar la función para crear la nueva columna "region_comercial"
        df['region_comercial'] = df['pais'].map(obtener_region_comercial)

        # Reorder columns for better read
        df = df[[
            'createdate',
            'deal_id',
            'dealname',
            'amount',
            'dealstage',
            'amount_weighted',
            'closedate',
            'days_to_close',
            'closed_won_reason',
            'closed_lost_reason',
            'pais',
            'region_comercial',
            'owner_id',
            'owner_assigneddate',
            'pipeline',
            'procedencia_del_lead',
            'canal_de_entrada',
            'canal_de_representacion',
            'presales',
            'tipo_de_venta',
            'bdr_prospecting_phase',
            #'deal_currency_code',
            #'hs_exchange_rate',
            #'amount_in_home_currency',
            'notes_last_updated',
            'notes_last_contacted',
            'hs_manual_forecast_category',
            'hs_forecast_probability',
            'hs_forecast_amount', 
            'last_modified',
            'associated_company',
            'associated_contact',
            'num_associated_contacts',
            'hs_num_of_associated_line_items',
            'hs_analytics_source',
            'hs_analytics_source_data_1',
            'hs_analytics_source_data_2',
            'hs_analytics_latest_source',
            'hs_analytics_latest_source_data_1',
            'hs_analytics_latest_source_data_2',
            'hs_analytics_latest_source_timestamp'
        ]]

        # Modificar el data type de columnas especificas
        df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
        df['days_to_close'] = pd.to_numeric(df['days_to_close'], errors='coerce').astype('Int64')
        df['amount_weighted'] = pd.to_numeric(df['amount_weighted'], errors='coerce')
        #df['hs_exchange_rate'] = pd.to_numeric(df['hs_exchange_rate'], errors='coerce')
        #df['amount_in_home_currency'] = pd.to_numeric(df['amount_in_home_currency'], errors='coerce')
        df['hs_forecast_probability'] = pd.to_numeric(df['hs_forecast_probability'], errors='coerce')
        df['hs_forecast_amount'] = pd.to_numeric(df['hs_forecast_amount'], errors='coerce')
        df['num_associated_contacts'] = pd.to_numeric(df['num_associated_contacts'], errors='coerce').astype('Int64')
        df['hs_num_of_associated_line_items'] = pd.to_numeric(df['hs_num_of_associated_line_items'], errors='coerce').astype('Int64')

        try:
            df.to_sql('hs_deals', con=engine, if_exists='replace', index=False)
            print(f"La tabla hs_deals se actualizó correctamente en la base de datos.")
            msg9 = "La tabla hs_deals se actualizó correctamente en la base de datos."
        except Exception as e:
            print(f"Error al intentar escribir en la base de datos: {str(e)}")
            msg9 = f"Error al intentar escribir en la base de datos: {str(e)}"

        return msg8, msg9
    
def update_database():

    # Definir las propiedades de cada entidad de hubspot que queremos incluir en la tabla

    hs_contacts_properties = {

        # vienen por default vienen por default con diccionario vacio
        # "createdate": 1,
        # "email": 1,
        # "firstname": 1,
        # "hs_object_id": 1,
        # "lastmodifieddate": 1,
        # "lastname": 1,

        # vienen por default vienen por default con diccionario al menos una propiedad requerida
        # "createdate": 1,
        # "hs_object_id": 1,
        # "lastmodifieddate": 1,
        "email": 1,
        "hs_email_domain": 1,
        "firstname": 1,
        "lastname": 1,
        "hs_lead_status": 1,
        "jobtitle": 1,
        "country": 1,
        "region": 1,
        "hubspot_owner_id": 1,
        "hubspot_owner_assigneddate": 1,
        "prospecto_de_inbound": 1,
        "canal_de_entrada": 1,
        "company": 1,
        "industry": 1,
        "recent_deal_amount": 1,
        "hs_marketable_status": 1,
        "hs_analytics_source": 1,
        "hs_analytics_source_data_1": 1,
        "hs_analytics_source_data_2": 1,
        "hs_latest_source": 1,
        "hs_latest_source_data_1": 1,
        "hs_latest_source_data_2": 1,
        "hs_latest_source_timestamp": 1,
        # asociaciones
        "num_associated_deals": 1,
        "num_notes": 1,
        "num_contacted_notes": 1,
        "notes_last_contacted": 1,
        #lifecycle related properties
        "lifecyclestage": 1,
        #"hs_lifecyclestage_subscriber_date": 1,
        #"hs_lifecyclestage_lead_date": 1,
        #"hs_lifecyclestage_marketingqualifiedlead_date": 1,
        #"hs_lifecyclestage_salesqualifiedlead_date": 1,
        #"hs_lifecyclestage_lead_date": 1,
        #"hs_lifecyclestage_opportunity_date": 1,
        #"hs_lifecyclestage_customer_date": 1,
        "hs_object_source_label": 1,
        "hs_predictivescoringtier": 1,
        # "": 1,
    }

    hs_companies_properties = {
        # vienen por default sin requerirlas:
        # "createdate": 1,
        # "domain": 1,
        # "hs_lastmodifieddate": 1,
        # "hs_object_id": 1,
        # "name": 1,
        # "": 1,  
    }
  
    hs_deals_properties = {
        
        # vienen por default sin requerirlas:
        # "hs_object_id": 1,
        # "createdate": 1,
        # "hs_lastmodifieddate": 1, Most recent timestamp of any property update for this deal. This includes HubSpot internal properties, which can be visible or hidden. This property is updated automatically.

        "dealname": 1,
        "amount": 1,
        "dealstage": 1,
        "hs_projected_amount": 1, # Returns the multiplication of the amount times the probability of the deal closing.
        "closedate": 1,
        "closed_won_reason": 1,
        "closed_lost_reason": 1,
        "days_to_close": 1,
        #"amount_in_home_currency": 1,
        #"deal_currency_code":1,
        #"hs_exchange_rate": 1,
        "pa_s": 1,
        "hubspot_owner_id": 1,
        "hubspot_owner_assigneddate": 1,
        "pipeline": 1,
        "procedencia": 1,
        "canal_de_entrada": 1,
        "canal_de_representaci_n": 1,
        "hs_manual_forecast_category": 1,
        "tipo_de_venta": 1,
        "bdr_prospecting_phase": 1,
        "presales": 1,
        #"asignacion_a_preventa": 1,
        "notes_last_updated": 1,
        "notes_last_contacted": 1,
        "hs_forecast_probability": 1,
        "hs_forecast_amount": 1, 

        # analytics properties
        "hs_analytics_source": 1, # Original Source Type
        "hs_analytics_source_data_1": 1, # Original Source Data 1
        "hs_analytics_source_data_2": 1, # Original Source Data 2
        "hs_analytics_latest_source": 1, # Latest Source
        "hs_analytics_latest_source_data_1": 1, # Latest Source Data 1
        "hs_analytics_latest_source_data_2": 1, # Latest Source Data 2
        "hs_analytics_latest_source_timestamp": 1, # Latest Source Timestamp

        # asociaciones
        "num_associated_contacts": 1,
        "hs_num_of_associated_line_items": 1,

        # creadas por resta para integracion con API
        "associated_company_proxy": 1,
        "associated_contact_proxy": 1,
        #"": 1
    }
    
    # se instancia la clase HuspotAPI
    h = HubspotAPI()

    # Hubspot Export
    msg1, msg2, msg3, msg4 = h.raw_export_contacts(hs_contacts_properties)
    msg5, msg6, msg7 = h.raw_export_companies(hs_companies_properties)
    msg8, msg9 = h.raw_export_deals(hs_deals_properties)

    # Imprimir en consola las 9 variables creadas como log
    print(msg1)
    print(msg2)
    print(msg3)
    print(msg4)
    print(msg5)
    print(msg6)
    print(msg7)
    print(msg8)
    print(msg9)

update_database()
# Out:
# Hubspot Contacts Export has gathered 100 Contacts
# Hubspot Contacts Export has gathered 200 Contacts
# Hubspot Contacts Export has gathered 300 Contacts
# Hubspot Contacts Export has gathered 400 Contacts
# Hubspot Contacts Export has gathered 500 Contacts
# Hubspot Contacts Export has gathered 600 Contacts
# Hubspot Contacts Export has gathered 700 Contacts
# Hubspot Contacts Export has gathered 800 Contacts
# Hubspot Contacts Export has gathered 900 Contacts
# Hubspot Contacts Export has gathered 1000 Contacts
# Hubspot Contacts Export has gathered 1100 Contacts
# Hubspot Contacts Export has gathered 1200 Contacts
# Hubspot Contacts Export has gathered 1300 Contacts
# Hubspot Contacts Export has gathered 1400 Contacts
# Hubspot Contacts Export has gathered 1500 Contacts
# Hubspot Contacts Export has gathered 1600 Contacts
# Hubspot Contacts Export has gathered 1700 Contacts
# Hubspot Contacts Export has gathered 1800 Contacts
# Hubspot Contacts Export has gathered 1900 Contacts
# Hubspot Contacts Export has gathered 2000 Contacts
# Hubspot Contacts Export has gathered 2100 Contacts
# Hubspot Contacts Export has gathered 2200 Contacts
# Hubspot Contacts Export has gathered 2300 Contacts
# Hubspot Contacts Export has gathered 2400 Contacts
# Hubspot Contacts Export has gathered 2500 Contacts
# Hubspot Contacts Export has gathered 2600 Contacts
# Hubspot Contacts Export has gathered 2700 Contacts
# Hubspot Contacts Export has gathered 2800 Contacts
# Hubspot Contacts Export has gathered 2900 Contacts
# Hubspot Contacts Export has gathered 3000 Contacts
# Hubspot Contacts Export has gathered 3100 Contacts
# Hubspot Contacts Export has gathered 3200 Contacts
# Hubspot Contacts Export has gathered 3300 Contacts
# Hubspot Contacts Export has gathered 3400 Contacts
# Hubspot Contacts Export has gathered 3500 Contacts
# Hubspot Contacts Export has gathered 3600 Contacts
# Hubspot Contacts Export has gathered 3700 Contacts
# Hubspot Contacts Export has gathered 3800 Contacts
# Hubspot Contacts Export has gathered 3900 Contacts
# Hubspot Contacts Export has gathered 4000 Contacts
# Hubspot Contacts Export has gathered 4100 Contacts
# Hubspot Contacts Export has gathered 4200 Contacts
# Hubspot Contacts Export has gathered 4300 Contacts
# Hubspot Contacts Export has gathered 4400 Contacts
# Hubspot Contacts Export has gathered 4500 Contacts
# Hubspot Contacts Export has gathered 4600 Contacts
# Hubspot Contacts Export has gathered 4700 Contacts
# Hubspot Contacts Export has gathered 4800 Contacts
# Hubspot Contacts Export has gathered 4900 Contacts
# Hubspot Contacts Export has gathered 5000 Contacts
# Hubspot Contacts Export has gathered 5100 Contacts
# Hubspot Contacts Export has gathered 5200 Contacts
# Hubspot Contacts Export has gathered 5300 Contacts
# Hubspot Contacts Export has gathered 5400 Contacts
# Hubspot Contacts Export has gathered 5500 Contacts
# Hubspot Contacts Export has gathered 5600 Contacts
# Hubspot Contacts Export has gathered 5700 Contacts
# Hubspot Contacts Export has gathered 5800 Contacts
# Hubspot Contacts Export has gathered 5900 Contacts
# Hubspot Contacts Export has gathered 6000 Contacts
# Hubspot Contacts Export has gathered 6100 Contacts
# Hubspot Contacts Export has gathered 6200 Contacts
# Hubspot Contacts Export has gathered 6300 Contacts
# Hubspot Contacts Export has gathered 6400 Contacts
# Hubspot Contacts Export has gathered 6500 Contacts
# Hubspot Contacts Export has gathered 6600 Contacts
# Hubspot Contacts Export has gathered 6700 Contacts
# Hubspot Contacts Export has gathered 6800 Contacts
# Hubspot Contacts Export has gathered 6900 Contacts
# Hubspot Contacts Export has gathered 7000 Contacts
# Hubspot Contacts Export has gathered 7100 Contacts
# Hubspot Contacts Export has gathered 7200 Contacts
# Hubspot Contacts Export has gathered 7300 Contacts
# Hubspot Contacts Export has gathered 7400 Contacts
# Hubspot Contacts Export has gathered 7500 Contacts
# Hubspot Contacts Export has gathered 7600 Contacts
# Hubspot Contacts Export has gathered 7700 Contacts
# Hubspot Contacts Export has gathered 7800 Contacts
# Hubspot Contacts Export has gathered 7900 Contacts
# Hubspot Contacts Export has gathered 8000 Contacts
# Hubspot Contacts Export has gathered 8100 Contacts
# Hubspot Contacts Export has gathered 8200 Contacts
# Hubspot Contacts Export has gathered 8300 Contacts
# Hubspot Contacts Export has gathered 8400 Contacts
# Hubspot Contacts Export has gathered 8500 Contacts
# Hubspot Contacts Export has gathered 8600 Contacts
# Hubspot Contacts Export has gathered 8700 Contacts
# Hubspot Contacts Export has gathered 8800 Contacts
# Hubspot Contacts Export has gathered 8900 Contacts
# Hubspot Contacts Export has gathered 9000 Contacts
# Hubspot Contacts Export has gathered 9100 Contacts
# Hubspot Contacts Export has gathered 9200 Contacts
# Hubspot Contacts Export has gathered 9300 Contacts
# Hubspot Contacts Export has gathered 9400 Contacts
# Hubspot Contacts Export has gathered 9500 Contacts
# Hubspot Contacts Export has gathered 9600 Contacts
# Hubspot Contacts Export has gathered 9700 Contacts
# Hubspot Contacts Export has gathered 9800 Contacts
# Hubspot Contacts Export has gathered 9900 Contacts
# Hubspot Contacts Export has gathered 10000 Contacts
# Hubspot Contacts Export has gathered 10100 Contacts
# Hubspot Contacts Export has gathered 10200 Contacts
# Hubspot Contacts Export has gathered 10300 Contacts
# Hubspot Contacts Export has gathered 10400 Contacts
# Hubspot Contacts Export has gathered 10500 Contacts
# Hubspot Contacts Export has gathered 10600 Contacts
# Hubspot Contacts Export has gathered 10700 Contacts
# Hubspot Contacts Export has gathered 10800 Contacts
# Hubspot Contacts Export has gathered 10900 Contacts
# Hubspot Contacts Export has gathered 11000 Contacts
# Hubspot Contacts Export has gathered 11100 Contacts
# Hubspot Contacts Export has gathered 11200 Contacts
# Hubspot Contacts Export has gathered 11300 Contacts
# Hubspot Contacts Export has gathered 11400 Contacts
# Hubspot Contacts Export has gathered 11500 Contacts
# Hubspot Contacts Export has gathered 11600 Contacts
# Hubspot Contacts Export has gathered 11700 Contacts
# Hubspot Contacts Export has gathered 11800 Contacts
# Hubspot Contacts Export has gathered 11900 Contacts
# Hubspot Contacts Export has gathered 12000 Contacts
# Hubspot Contacts Export has gathered 12100 Contacts
# Hubspot Contacts Export has gathered 12200 Contacts
# Hubspot Contacts Export has gathered 12300 Contacts
# Hubspot Contacts Export has gathered 12400 Contacts
# Hubspot Contacts Export has gathered 12500 Contacts
# Hubspot Contacts Export has gathered 12600 Contacts
# Hubspot Contacts Export has gathered 12700 Contacts
# Hubspot Contacts Export has gathered 12800 Contacts
# Hubspot Contacts Export has gathered 12900 Contacts
# Hubspot Contacts Export has gathered 13000 Contacts
# Hubspot Contacts Export has gathered 13100 Contacts
# Hubspot Contacts Export has gathered 13200 Contacts
# Hubspot Contacts Export has gathered 13300 Contacts
# Hubspot Contacts Export has gathered 13400 Contacts
# Hubspot Contacts Export has gathered 13500 Contacts
# Hubspot Contacts Export has gathered 13600 Contacts
# Hubspot Contacts Export has gathered 13700 Contacts
# Hubspot Contacts Export has gathered 13800 Contacts
# Hubspot Contacts Export has gathered 13900 Contacts
# Hubspot Contacts Export has gathered 14000 Contacts
# Hubspot Contacts Export has gathered 14100 Contacts
# Hubspot Contacts Export has gathered 14200 Contacts
# Hubspot Contacts Export has gathered 14300 Contacts
# Hubspot Contacts Export has gathered 14400 Contacts
# Hubspot Contacts Export has gathered 14500 Contacts
# Hubspot Contacts Export has gathered 14600 Contacts
# Hubspot Contacts Export has gathered 14700 Contacts
# Hubspot Contacts Export has gathered 14800 Contacts
# Hubspot Contacts Export has gathered 14900 Contacts
# Hubspot Contacts Export has gathered 15000 Contacts
# Hubspot Contacts Export has gathered 15100 Contacts
# Hubspot Contacts Export has gathered 15200 Contacts
# Hubspot Contacts Export has gathered 15300 Contacts
# Hubspot Contacts Export has gathered 15400 Contacts
# Hubspot Contacts Export has gathered 15500 Contacts
# Hubspot Contacts Export has gathered 15600 Contacts
# Hubspot Contacts Export has gathered 15700 Contacts
# Hubspot Contacts Export has gathered 15800 Contacts
# Hubspot Contacts Export has gathered 15900 Contacts
# Hubspot Contacts Export has gathered 16000 Contacts
# Hubspot Contacts Export has gathered 16100 Contacts
# Hubspot Contacts Export has gathered 16200 Contacts
# Hubspot Contacts Export has gathered 16300 Contacts
# Hubspot Contacts Export has gathered 16400 Contacts
# Hubspot Contacts Export has gathered 16500 Contacts
# Hubspot Contacts Export has gathered 16600 Contacts
# Hubspot Contacts Export has gathered 16700 Contacts
# Hubspot Contacts Export has gathered 16800 Contacts
# Hubspot Contacts Export has gathered 16900 Contacts
# Hubspot Contacts Export has gathered 17000 Contacts
# Hubspot Contacts Export has gathered 17100 Contacts
# Hubspot Contacts Export has gathered 17200 Contacts
# Hubspot Contacts Export has gathered 17300 Contacts
# Hubspot Contacts Export has gathered 17400 Contacts
# Hubspot Contacts Export has gathered 17500 Contacts
# Hubspot Contacts Export has gathered 17600 Contacts
# Hubspot Contacts Export has gathered 17700 Contacts
# Hubspot Contacts Export has gathered 17800 Contacts
# Hubspot Contacts Export has gathered 17900 Contacts
# Hubspot Contacts Export has gathered 18000 Contacts
# Hubspot Contacts Export has gathered 18100 Contacts
# Hubspot Contacts Export has gathered 18200 Contacts
# Hubspot Contacts Export has gathered 18300 Contacts
# Hubspot Contacts Export has gathered 18400 Contacts
# Hubspot Contacts Export has gathered 18500 Contacts
# Hubspot Contacts Export has gathered 18600 Contacts
# Hubspot Contacts Export has gathered 18700 Contacts
# Hubspot Contacts Export has gathered 18800 Contacts
# Hubspot Contacts Export has gathered 18900 Contacts
# Hubspot Contacts Export has gathered 19000 Contacts
# Hubspot Contacts Export has gathered 19100 Contacts
# Hubspot Contacts Export has gathered 19200 Contacts
# Hubspot Contacts Export has gathered 19300 Contacts
# Hubspot Contacts Export has gathered 19400 Contacts
# Hubspot Contacts Export has gathered 19500 Contacts
# Hubspot Contacts Export has gathered 19600 Contacts
# Hubspot Contacts Export has gathered 19700 Contacts
# Hubspot Contacts Export has gathered 19800 Contacts
# Hubspot Contacts Export has gathered 19900 Contacts
# Hubspot Contacts Export has gathered 20000 Contacts
# Hubspot Contacts Export has gathered 20100 Contacts
# Hubspot Contacts Export has gathered 20200 Contacts
# Hubspot Contacts Export has gathered 20300 Contacts
# Hubspot Contacts Export has gathered 20400 Contacts
# Hubspot Contacts Export has gathered 20500 Contacts
# Hubspot Contacts Export has gathered 20600 Contacts
# Hubspot Contacts Export has gathered 20700 Contacts
# Hubspot Contacts Export has gathered 20800 Contacts
# Hubspot Contacts Export has gathered 20900 Contacts
# Hubspot Contacts Export has gathered 21000 Contacts
# Hubspot Contacts Export has gathered 21100 Contacts
# Hubspot Contacts Export has gathered 21200 Contacts
# Hubspot Contacts Export has gathered 21300 Contacts
# Hubspot Contacts Export has gathered 21400 Contacts
# Hubspot Contacts Export has gathered 21500 Contacts
# Hubspot Contacts Export has gathered 21600 Contacts
# Hubspot Contacts Export has gathered 21700 Contacts
# Hubspot Contacts Export has gathered 21800 Contacts
# Hubspot Contacts Export has gathered 21900 Contacts
# Hubspot Contacts Export has gathered 22000 Contacts
# Hubspot Contacts Export has gathered 22100 Contacts
# Hubspot Contacts Export has gathered 22200 Contacts
# Hubspot Contacts Export has gathered 22300 Contacts
# Hubspot Contacts Export has gathered 22400 Contacts
# Hubspot Contacts Export has gathered 22500 Contacts
# Hubspot Contacts Export has gathered 22600 Contacts
# Hubspot Contacts Export has gathered 22700 Contacts
# Hubspot Contacts Export has gathered 22800 Contacts
# Hubspot Contacts Export has gathered 22900 Contacts
# Hubspot Contacts Export has gathered 23000 Contacts
# Hubspot Contacts Export has gathered 23100 Contacts
# Hubspot Contacts Export has gathered 23200 Contacts
# Hubspot Contacts Export has gathered 23300 Contacts
# Hubspot Contacts Export has gathered 23400 Contacts
# Hubspot Contacts Export has gathered 23500 Contacts
# Hubspot Contacts Export has gathered 23600 Contacts
# Hubspot Contacts Export has gathered 23700 Contacts
# Hubspot Contacts Export has gathered 23800 Contacts
# Hubspot Contacts Export has gathered 23900 Contacts
# Hubspot Contacts Export has gathered 24000 Contacts
# Hubspot Contacts Export has gathered 24100 Contacts
# Hubspot Contacts Export has gathered 24200 Contacts
# Hubspot Contacts Export has gathered 24300 Contacts
# Hubspot Contacts Export has gathered 24400 Contacts
# Hubspot Contacts Export has gathered 24500 Contacts
# Hubspot Contacts Export has gathered 24600 Contacts
# Hubspot Contacts Export has gathered 24700 Contacts
# Hubspot Contacts Export has gathered 24800 Contacts
# Hubspot Contacts Export has gathered 24900 Contacts
# Hubspot Contacts Export has gathered 25000 Contacts
# Hubspot Contacts Export has gathered 25100 Contacts
# Hubspot Contacts Export has gathered 25200 Contacts
# Hubspot Contacts Export has gathered 25300 Contacts
# Hubspot Contacts Export has gathered 25400 Contacts
# Hubspot Contacts Export has gathered 25500 Contacts
# Hubspot Contacts Export has gathered 25600 Contacts
# Hubspot Contacts Export has gathered 25700 Contacts
# Hubspot Contacts Export has gathered 25800 Contacts
# Hubspot Contacts Export has gathered 25900 Contacts
# Hubspot Contacts Export has gathered 26000 Contacts
# Hubspot Contacts Export has gathered 26100 Contacts
# Hubspot Contacts Export has gathered 26200 Contacts
# Hubspot Contacts Export has gathered 26300 Contacts
# Hubspot Contacts Export has gathered 26400 Contacts
# Hubspot Contacts Export has gathered 26500 Contacts
# Hubspot Contacts Export has gathered 26600 Contacts
# Hubspot Contacts Export has gathered 26700 Contacts
# Hubspot Contacts Export has gathered 26800 Contacts
# Hubspot Contacts Export has gathered 26900 Contacts
# Hubspot Contacts Export has gathered 27000 Contacts
# Hubspot Contacts Export has gathered 27100 Contacts
# Hubspot Contacts Export has gathered 27200 Contacts
# Hubspot Contacts Export has gathered 27300 Contacts
# Hubspot Contacts Export has gathered 27400 Contacts
# Hubspot Contacts Export has gathered 27500 Contacts
# Hubspot Contacts Export has gathered 27600 Contacts
# Hubspot Contacts Export has gathered 27700 Contacts
# Hubspot Contacts Export has gathered 27800 Contacts
# Hubspot Contacts Export has gathered 27900 Contacts
# Hubspot Contacts Export has gathered 28000 Contacts
# Hubspot Contacts Export has gathered 28100 Contacts
# Hubspot Contacts Export has gathered 28200 Contacts
# Hubspot Contacts Export has gathered 28300 Contacts
# Hubspot Contacts Export has gathered 28400 Contacts
# Hubspot Contacts Export has gathered 28500 Contacts
# Hubspot Contacts Export has gathered 28600 Contacts
# Hubspot Contacts Export has gathered 28700 Contacts
# Hubspot Contacts Export has gathered 28800 Contacts
# Hubspot Contacts Export has gathered 28900 Contacts
# Hubspot Contacts Export has gathered 29000 Contacts
# Hubspot Contacts Export has gathered 29100 Contacts
# Hubspot Contacts Export has gathered 29200 Contacts
# Hubspot Contacts Export has gathered 29300 Contacts
# Hubspot Contacts Export has gathered 29400 Contacts
# Hubspot Contacts Export has gathered 29500 Contacts
# Hubspot Contacts Export has gathered 29600 Contacts
# Hubspot Contacts Export has gathered 29700 Contacts
# Hubspot Contacts Export has gathered 29800 Contacts
# Hubspot Contacts Export has gathered 29900 Contacts
# Hubspot Contacts Export has gathered 30000 Contacts
# Hubspot Contacts Export has gathered 30100 Contacts
# Hubspot Contacts Export has gathered 30200 Contacts
# Hubspot Contacts Export has gathered 30300 Contacts
# Hubspot Contacts Export has gathered 30400 Contacts
# Hubspot Contacts Export has gathered 30500 Contacts
# Hubspot Contacts Export has gathered 30600 Contacts
# Hubspot Contacts Export has gathered 30700 Contacts
# Hubspot Contacts Export has gathered 30800 Contacts
# Hubspot Contacts Export has gathered 30900 Contacts
# Hubspot Contacts Export has gathered 31000 Contacts
# Hubspot Contacts Export has gathered 31100 Contacts
# Hubspot Contacts Export has gathered 31200 Contacts
# Hubspot Contacts Export has gathered 31300 Contacts
# Hubspot Contacts Export has gathered 31400 Contacts
# Hubspot Contacts Export has gathered 31500 Contacts
# Hubspot Contacts Export has gathered 31600 Contacts
# Hubspot Contacts Export has gathered 31700 Contacts
# Hubspot Contacts Export has gathered 31800 Contacts
# Hubspot Contacts Export has gathered 31900 Contacts
# Hubspot Contacts Export has gathered 32000 Contacts
# Hubspot Contacts Export has gathered 32100 Contacts
# Hubspot Contacts Export has gathered 32200 Contacts
# Hubspot Contacts Export has gathered 32300 Contacts
# Hubspot Contacts Export has gathered 32400 Contacts
# Hubspot Contacts Export has gathered 32500 Contacts
# Hubspot Contacts Export has gathered 32600 Contacts
# Hubspot Contacts Export has gathered 32700 Contacts
# Hubspot Contacts Export has gathered 32800 Contacts
# Hubspot Contacts Export has gathered 32900 Contacts
# Hubspot Contacts Export has gathered 33000 Contacts
# Hubspot Contacts Export has gathered 33100 Contacts
# Hubspot Contacts Export has gathered 33200 Contacts
# Hubspot Contacts Export has gathered 33300 Contacts
# Hubspot Contacts Export has gathered 33400 Contacts
# Hubspot Contacts Export has gathered 33500 Contacts
# Hubspot Contacts Export has gathered 33600 Contacts
# Hubspot Contacts Export has gathered 33700 Contacts
# Hubspot Contacts Export has gathered 33800 Contacts
# Hubspot Contacts Export has gathered 33900 Contacts
# Hubspot Contacts Export has gathered 34000 Contacts
# Hubspot Contacts Export has gathered 34100 Contacts
# Hubspot Contacts Export has gathered 34200 Contacts
# Hubspot Contacts Export has gathered 34300 Contacts
# Hubspot Contacts Export has gathered 34400 Contacts
# Hubspot Contacts Export has gathered 34500 Contacts
# Hubspot Contacts Export has gathered 34600 Contacts
# Hubspot Contacts Export has gathered 34700 Contacts
# Hubspot Contacts Export has gathered 34800 Contacts
# Hubspot Contacts Export has gathered 34900 Contacts
# Hubspot Contacts Export has gathered 35000 Contacts
# Hubspot Contacts Export has gathered 35100 Contacts
# Hubspot Contacts Export has gathered 35200 Contacts
# Hubspot Contacts Export has gathered 35300 Contacts
# Hubspot Contacts Export has gathered 35400 Contacts
# Hubspot Contacts Export has gathered 35500 Contacts
# Hubspot Contacts Export has gathered 35600 Contacts
# Hubspot Contacts Export has gathered 35700 Contacts
# Hubspot Contacts Export has gathered 35800 Contacts
# Hubspot Contacts Export has gathered 35900 Contacts
# Hubspot Contacts Export has gathered 36000 Contacts
# Hubspot Contacts Export has gathered 36100 Contacts
# Hubspot Contacts Export has gathered 36200 Contacts
# Hubspot Contacts Export has gathered 36300 Contacts
# Hubspot Contacts Export has gathered 36400 Contacts
# Hubspot Contacts Export has gathered 36500 Contacts
# Hubspot Contacts Export has gathered 36600 Contacts
# Hubspot Contacts Export has gathered 36700 Contacts
# Hubspot Contacts Export has gathered 36800 Contacts
# Hubspot Contacts Export has gathered 36900 Contacts
# Hubspot Contacts Export has gathered 37000 Contacts
# Hubspot Contacts Export has gathered 37100 Contacts
# Hubspot Contacts Export has gathered 37200 Contacts
# Hubspot Contacts Export has gathered 37300 Contacts
# Hubspot Contacts Export has gathered 37400 Contacts
# Hubspot Contacts Export has gathered 37500 Contacts
# Hubspot Contacts Export has gathered 37600 Contacts
# Hubspot Contacts Export has gathered 37700 Contacts
# Hubspot Contacts Export has gathered 37800 Contacts
# Hubspot Contacts Export has gathered 37900 Contacts
# Hubspot Contacts Export has gathered 38000 Contacts
# Hubspot Contacts Export has gathered 38100 Contacts
# Hubspot Contacts Export has gathered 38200 Contacts
# Hubspot Contacts Export has gathered 38300 Contacts
# Hubspot Contacts Export has gathered 38400 Contacts
# Hubspot Contacts Export has gathered 38500 Contacts
# Hubspot Contacts Export has gathered 38600 Contacts
# Hubspot Contacts Export has gathered 38700 Contacts
# Hubspot Contacts Export has gathered 38800 Contacts
# Hubspot Contacts Export has gathered 38900 Contacts
# Hubspot Contacts Export has gathered 39000 Contacts
# Hubspot Contacts Export has gathered 39100 Contacts
# Hubspot Contacts Export has gathered 39200 Contacts
# Hubspot Contacts Export has gathered 39300 Contacts
# Hubspot Contacts Export has gathered 39400 Contacts
# Hubspot Contacts Export has gathered 39500 Contacts
# Hubspot Contacts Export has gathered 39600 Contacts
# Hubspot Contacts Export has gathered 39700 Contacts
# Hubspot Contacts Export has gathered 39800 Contacts
# Hubspot Contacts Export has gathered 39900 Contacts
# Hubspot Contacts Export has gathered 40000 Contacts
# Hubspot Contacts Export has gathered 40100 Contacts
# Hubspot Contacts Export has gathered 40200 Contacts
# Hubspot Contacts Export has gathered 40300 Contacts
# Hubspot Contacts Export has gathered 40400 Contacts
# Hubspot Contacts Export has gathered 40500 Contacts
# Hubspot Contacts Export has gathered 40600 Contacts
# Hubspot Contacts Export has gathered 40700 Contacts
# Hubspot Contacts Export has gathered 40800 Contacts
# Hubspot Contacts Export has gathered 40900 Contacts
# Hubspot Contacts Export has gathered 41000 Contacts
# Hubspot Contacts Export has gathered 41100 Contacts
# Hubspot Contacts Export has gathered 41200 Contacts
# Hubspot Contacts Export has gathered 41300 Contacts
# Hubspot Contacts Export has gathered 41400 Contacts
# Hubspot Contacts Export has gathered 41500 Contacts
# Hubspot Contacts Export has gathered 41600 Contacts
# Hubspot Contacts Export has gathered 41700 Contacts
# Hubspot Contacts Export has gathered 41800 Contacts
# Hubspot Contacts Export has gathered 41900 Contacts
# Hubspot Contacts Export has gathered 42000 Contacts
# Hubspot Contacts Export has gathered 42100 Contacts
# Hubspot Contacts Export has gathered 42200 Contacts
# Hubspot Contacts Export has gathered 42300 Contacts
# Hubspot Contacts Export has gathered 42400 Contacts
# Hubspot Contacts Export has gathered 42500 Contacts
# Hubspot Contacts Export has gathered 42600 Contacts
# Hubspot Contacts Export has gathered 42700 Contacts
# Hubspot Contacts Export has gathered 42800 Contacts
# Hubspot Contacts Export has gathered 42900 Contacts
# Hubspot Contacts Export has gathered 43000 Contacts
# Hubspot Contacts Export has gathered 43100 Contacts
# Hubspot Contacts Export has gathered 43200 Contacts
# Hubspot Contacts Export has gathered 43300 Contacts
# Hubspot Contacts Export has gathered 43400 Contacts
# Hubspot Contacts Export has gathered 43500 Contacts
# Hubspot Contacts Export has gathered 43600 Contacts
# Hubspot Contacts Export has gathered 43700 Contacts
# Hubspot Contacts Export has gathered 43800 Contacts
# Hubspot Contacts Export has gathered 43900 Contacts
# Hubspot Contacts Export has gathered 44000 Contacts
# Hubspot Contacts Export has gathered 44100 Contacts
# Hubspot Contacts Export has gathered 44200 Contacts
# Hubspot Contacts Export has gathered 44300 Contacts
# Hubspot Contacts Export has gathered 44400 Contacts
# Hubspot Contacts Export has gathered 44500 Contacts
# Hubspot Contacts Export has gathered 44600 Contacts
# Hubspot Contacts Export has gathered 44700 Contacts
# Hubspot Contacts Export has gathered 44800 Contacts
# Hubspot Contacts Export has gathered 44900 Contacts
# Hubspot Contacts Export has gathered 45000 Contacts
# Hubspot Contacts Export has gathered 45100 Contacts
# Hubspot Contacts Export has gathered 45200 Contacts
# Hubspot Contacts Export has gathered 45300 Contacts
# Hubspot Contacts Export has gathered 45400 Contacts
# Hubspot Contacts Export has gathered 45500 Contacts
# Hubspot Contacts Export has gathered 45600 Contacts
# Hubspot Contacts Export has gathered 45700 Contacts
# Hubspot Contacts Export has gathered 45800 Contacts
# Hubspot Contacts Export has gathered 45900 Contacts
# Hubspot Contacts Export has gathered 46000 Contacts
# Hubspot Contacts Export has gathered 46100 Contacts
# Hubspot Contacts Export has gathered 46200 Contacts
# Hubspot Contacts Export has gathered 46300 Contacts
# Hubspot Contacts Export has gathered 46400 Contacts
# Hubspot Contacts Export has gathered 46500 Contacts
# Hubspot Contacts Export has gathered 46600 Contacts
# Hubspot Contacts Export has gathered 46700 Contacts
# Hubspot Contacts Export has gathered 46800 Contacts
# Hubspot Contacts Export has gathered 46900 Contacts
# Hubspot Contacts Export has gathered 47000 Contacts
# Hubspot Contacts Export has gathered 47100 Contacts
# Hubspot Contacts Export has gathered 47200 Contacts
# Hubspot Contacts Export has gathered 47300 Contacts
# Hubspot Contacts Export has gathered 47400 Contacts
# Hubspot Contacts Export has gathered 47500 Contacts
# Hubspot Contacts Export has gathered 47600 Contacts
# Hubspot Contacts Export has gathered 47700 Contacts
# Hubspot Contacts Export has gathered 47800 Contacts
# Hubspot Contacts Export has gathered 47900 Contacts
# Hubspot Contacts Export has gathered 48000 Contacts
# Hubspot Contacts Export has gathered 48100 Contacts
# Hubspot Contacts Export has gathered 48200 Contacts
# Hubspot Contacts Export has gathered 48300 Contacts
# Hubspot Contacts Export has gathered 48400 Contacts
# Hubspot Contacts Export has gathered 48500 Contacts
# Hubspot Contacts Export has gathered 48600 Contacts
# Hubspot Contacts Export has gathered 48700 Contacts
# Hubspot Contacts Export has gathered 48800 Contacts
# Hubspot Contacts Export has gathered 48900 Contacts
# Hubspot Contacts Export has gathered 49000 Contacts
# Hubspot Contacts Export has gathered 49100 Contacts
# Hubspot Contacts Export has gathered 49200 Contacts
# Hubspot Contacts Export has gathered 49300 Contacts
# Hubspot Contacts Export has gathered 49400 Contacts
# Hubspot Contacts Export has gathered 49500 Contacts
# Hubspot Contacts Export has gathered 49600 Contacts
# Hubspot Contacts Export has gathered 49700 Contacts
# Hubspot Contacts Export has gathered 49800 Contacts
# Hubspot Contacts Export has gathered 49900 Contacts
# Hubspot Contacts Export has gathered 50000 Contacts
# Hubspot Contacts Export has gathered 50100 Contacts
# Hubspot Contacts Export has gathered 50200 Contacts
# Hubspot Contacts Export has gathered 50300 Contacts
# Hubspot Contacts Export has gathered 50400 Contacts
# Hubspot Contacts Export has gathered 50500 Contacts
# Hubspot Contacts Export has gathered 50600 Contacts
# Hubspot Contacts Export has gathered 50700 Contacts
# Hubspot Contacts Export has gathered 50800 Contacts
# Hubspot Contacts Export has gathered 50900 Contacts
# Hubspot Contacts Export has gathered 51000 Contacts
# Hubspot Contacts Export has gathered 51100 Contacts
# Hubspot Contacts Export has gathered 51200 Contacts
# Hubspot Contacts Export has gathered 51300 Contacts
# Hubspot Contacts Export has gathered 51400 Contacts
# Hubspot Contacts Export has gathered 51500 Contacts
# Hubspot Contacts Export has gathered 51600 Contacts
# Hubspot Contacts Export has gathered 51700 Contacts
# Hubspot Contacts Export has gathered 51800 Contacts
# Hubspot Contacts Export has gathered 51900 Contacts
# Hubspot Contacts Export has gathered 52000 Contacts
# Hubspot Contacts Export has gathered 52100 Contacts
# Hubspot Contacts Export has gathered 52200 Contacts
# Hubspot Contacts Export has gathered 52300 Contacts
# Hubspot Contacts Export has gathered 52400 Contacts
# Hubspot Contacts Export has gathered 52500 Contacts
# Hubspot Contacts Export has gathered 52600 Contacts
# Hubspot Contacts Export has gathered 52700 Contacts
# Hubspot Contacts Export has gathered 52800 Contacts
# Hubspot Contacts Export has gathered 52900 Contacts
# Hubspot Contacts Export has gathered 53000 Contacts
# Hubspot Contacts Export has gathered 53100 Contacts
# Hubspot Contacts Export has gathered 53200 Contacts
# Hubspot Contacts Export has gathered 53300 Contacts
# Hubspot Contacts Export has gathered 53400 Contacts
# Hubspot Contacts Export has gathered 53500 Contacts
# Hubspot Contacts Export has gathered 53600 Contacts
# Hubspot Contacts Export has gathered 53700 Contacts
# Hubspot Contacts Export has gathered 53800 Contacts
# Hubspot Contacts Export has gathered 53900 Contacts
# Hubspot Contacts Export has gathered 54000 Contacts
# Hubspot Contacts Export has gathered 54100 Contacts
# Hubspot Contacts Export has gathered 54200 Contacts
# Hubspot Contacts Export has gathered 54300 Contacts
# Hubspot Contacts Export has gathered 54400 Contacts
# Hubspot Contacts Export has gathered 54500 Contacts
# Hubspot Contacts Export has gathered 54600 Contacts
# Hubspot Contacts Export has gathered 54700 Contacts
# Hubspot Contacts Export has gathered 54800 Contacts
# Hubspot Contacts Export has gathered 54900 Contacts
# Hubspot Contacts Export has gathered 55000 Contacts
# Hubspot Contacts Export has gathered 55100 Contacts
# Hubspot Contacts Export has gathered 55200 Contacts
# Hubspot Contacts Export has gathered 55300 Contacts
# Hubspot Contacts Export has gathered 55400 Contacts
# Hubspot Contacts Export has gathered 55500 Contacts
# Hubspot Contacts Export has gathered 55600 Contacts
# Hubspot Contacts Export has gathered 55700 Contacts
# Hubspot Contacts Export has gathered 55800 Contacts
# Hubspot Contacts Export has gathered 55900 Contacts
# Hubspot Contacts Export has gathered 56000 Contacts
# Hubspot Contacts Export has gathered 56100 Contacts
# Hubspot Contacts Export has gathered 56200 Contacts
# Hubspot Contacts Export has gathered 56300 Contacts
# Hubspot Contacts Export has gathered 56400 Contacts
# Hubspot Contacts Export has gathered 56500 Contacts
# Hubspot Contacts Export has gathered 56600 Contacts
# Hubspot Contacts Export has gathered 56700 Contacts
# Hubspot Contacts Export has gathered 56800 Contacts
# Hubspot Contacts Export has gathered 56900 Contacts
# Hubspot Contacts Export has gathered 57000 Contacts
# Hubspot Contacts Export has gathered 57100 Contacts
# Hubspot Contacts Export has gathered 57200 Contacts
# Hubspot Contacts Export has gathered 57300 Contacts
# Hubspot Contacts Export has gathered 57400 Contacts
# Hubspot Contacts Export has gathered 57500 Contacts
# Hubspot Contacts Export has gathered 57600 Contacts
# Hubspot Contacts Export has gathered 57700 Contacts
# Hubspot Contacts Export has gathered 57800 Contacts
# Hubspot Contacts Export has gathered 57900 Contacts
# Hubspot Contacts Export has gathered 58000 Contacts
# Hubspot Contacts Export has gathered 58100 Contacts
# Hubspot Contacts Export has gathered 58200 Contacts
# Hubspot Contacts Export has gathered 58300 Contacts
# Hubspot Contacts Export has gathered 58400 Contacts
# Hubspot Contacts Export has gathered 58500 Contacts
# Hubspot Contacts Export has gathered 58600 Contacts
# Hubspot Contacts Export has gathered 58700 Contacts
# Hubspot Contacts Export has gathered 58800 Contacts
# Hubspot Contacts Export has gathered 58900 Contacts
# Hubspot Contacts Export has gathered 58948 Contacts
# La tabla hs_contacts se actualizó correctamente en la base de datos.
# La tabla hs_contacts_to_deals se actualizó correctamente en la base de datos.
# La tabla hs_contacts_to_companies se actualizó correctamente en la base de datos.
# Hubspot Companies Export has gathered 100 Companies
# Hubspot Companies Export has gathered 200 Companies
# Hubspot Companies Export has gathered 300 Companies
# Hubspot Companies Export has gathered 400 Companies
# Hubspot Companies Export has gathered 500 Companies
# Hubspot Companies Export has gathered 600 Companies
# Hubspot Companies Export has gathered 700 Companies
# Hubspot Companies Export has gathered 800 Companies
# Hubspot Companies Export has gathered 900 Companies
# Hubspot Companies Export has gathered 1000 Companies
# Hubspot Companies Export has gathered 1100 Companies
# Hubspot Companies Export has gathered 1200 Companies
# Hubspot Companies Export has gathered 1300 Companies
# Hubspot Companies Export has gathered 1400 Companies
# Hubspot Companies Export has gathered 1500 Companies
# Hubspot Companies Export has gathered 1600 Companies
# Hubspot Companies Export has gathered 1700 Companies
# Hubspot Companies Export has gathered 1800 Companies
# Hubspot Companies Export has gathered 1900 Companies
# Hubspot Companies Export has gathered 2000 Companies
# Hubspot Companies Export has gathered 2100 Companies
# Hubspot Companies Export has gathered 2200 Companies
# Hubspot Companies Export has gathered 2300 Companies
# Hubspot Companies Export has gathered 2400 Companies
# Hubspot Companies Export has gathered 2500 Companies
# Hubspot Companies Export has gathered 2600 Companies
# Hubspot Companies Export has gathered 2700 Companies
# Hubspot Companies Export has gathered 2800 Companies
# Hubspot Companies Export has gathered 2900 Companies
# Hubspot Companies Export has gathered 3000 Companies
# Hubspot Companies Export has gathered 3100 Companies
# Hubspot Companies Export has gathered 3200 Companies
# Hubspot Companies Export has gathered 3300 Companies
# Hubspot Companies Export has gathered 3400 Companies
# Hubspot Companies Export has gathered 3500 Companies
# Hubspot Companies Export has gathered 3600 Companies
# Hubspot Companies Export has gathered 3700 Companies
# Hubspot Companies Export has gathered 3800 Companies
# Hubspot Companies Export has gathered 3900 Companies
# Hubspot Companies Export has gathered 4000 Companies
# Hubspot Companies Export has gathered 4100 Companies
# Hubspot Companies Export has gathered 4200 Companies
# Hubspot Companies Export has gathered 4300 Companies
# Hubspot Companies Export has gathered 4400 Companies
# Hubspot Companies Export has gathered 4500 Companies
# Hubspot Companies Export has gathered 4600 Companies
# Hubspot Companies Export has gathered 4700 Companies
# Hubspot Companies Export has gathered 4800 Companies
# Hubspot Companies Export has gathered 4900 Companies
# Hubspot Companies Export has gathered 5000 Companies
# Hubspot Companies Export has gathered 5100 Companies
# Hubspot Companies Export has gathered 5200 Companies
# Hubspot Companies Export has gathered 5300 Companies
# Hubspot Companies Export has gathered 5400 Companies
# Hubspot Companies Export has gathered 5500 Companies
# Hubspot Companies Export has gathered 5600 Companies
# Hubspot Companies Export has gathered 5700 Companies
# Hubspot Companies Export has gathered 5800 Companies
# Hubspot Companies Export has gathered 5900 Companies
# Hubspot Companies Export has gathered 6000 Companies
# Hubspot Companies Export has gathered 6100 Companies
# Hubspot Companies Export has gathered 6200 Companies
# Hubspot Companies Export has gathered 6300 Companies
# Hubspot Companies Export has gathered 6400 Companies
# Hubspot Companies Export has gathered 6500 Companies
# Hubspot Companies Export has gathered 6600 Companies
# Hubspot Companies Export has gathered 6700 Companies
# Hubspot Companies Export has gathered 6800 Companies
# Hubspot Companies Export has gathered 6900 Companies
# Hubspot Companies Export has gathered 7000 Companies
# Hubspot Companies Export has gathered 7100 Companies
# Hubspot Companies Export has gathered 7200 Companies
# Hubspot Companies Export has gathered 7300 Companies
# Hubspot Companies Export has gathered 7400 Companies
# Hubspot Companies Export has gathered 7500 Companies
# Hubspot Companies Export has gathered 7600 Companies
# Hubspot Companies Export has gathered 7700 Companies
# Hubspot Companies Export has gathered 7800 Companies
# Hubspot Companies Export has gathered 7900 Companies
# Hubspot Companies Export has gathered 8000 Companies
# Hubspot Companies Export has gathered 8100 Companies
# Hubspot Companies Export has gathered 8200 Companies
# Hubspot Companies Export has gathered 8300 Companies
# Hubspot Companies Export has gathered 8400 Companies
# Hubspot Companies Export has gathered 8500 Companies
# Hubspot Companies Export has gathered 8600 Companies
# Hubspot Companies Export has gathered 8700 Companies
# Hubspot Companies Export has gathered 8800 Companies
# Hubspot Companies Export has gathered 8900 Companies
# Hubspot Companies Export has gathered 9000 Companies
# Hubspot Companies Export has gathered 9100 Companies
# Hubspot Companies Export has gathered 9200 Companies
# Hubspot Companies Export has gathered 9300 Companies
# Hubspot Companies Export has gathered 9400 Companies
# Hubspot Companies Export has gathered 9500 Companies
# Hubspot Companies Export has gathered 9600 Companies
# Hubspot Companies Export has gathered 9700 Companies
# Hubspot Companies Export has gathered 9800 Companies
# Hubspot Companies Export has gathered 9900 Companies
# Hubspot Companies Export has gathered 10000 Companies
# Hubspot Companies Export has gathered 10100 Companies
# Hubspot Companies Export has gathered 10200 Companies
# Hubspot Companies Export has gathered 10300 Companies
# Hubspot Companies Export has gathered 10400 Companies
# Hubspot Companies Export has gathered 10500 Companies
# Hubspot Companies Export has gathered 10600 Companies
# Hubspot Companies Export has gathered 10700 Companies
# Hubspot Companies Export has gathered 10800 Companies
# Hubspot Companies Export has gathered 10900 Companies
# Hubspot Companies Export has gathered 11000 Companies
# Hubspot Companies Export has gathered 11100 Companies
# Hubspot Companies Export has gathered 11200 Companies
# Hubspot Companies Export has gathered 11300 Companies
# Hubspot Companies Export has gathered 11400 Companies
# Hubspot Companies Export has gathered 11500 Companies
# Hubspot Companies Export has gathered 11600 Companies
# Hubspot Companies Export has gathered 11700 Companies
# Hubspot Companies Export has gathered 11800 Companies
# Hubspot Companies Export has gathered 11900 Companies
# Hubspot Companies Export has gathered 12000 Companies
# Hubspot Companies Export has gathered 12100 Companies
# Hubspot Companies Export has gathered 12200 Companies
# Hubspot Companies Export has gathered 12300 Companies
# Hubspot Companies Export has gathered 12400 Companies
# Hubspot Companies Export has gathered 12500 Companies
# Hubspot Companies Export has gathered 12600 Companies
# Hubspot Companies Export has gathered 12700 Companies
# Hubspot Companies Export has gathered 12800 Companies
# Hubspot Companies Export has gathered 12900 Companies
# Hubspot Companies Export has gathered 13000 Companies
# Hubspot Companies Export has gathered 13100 Companies
# Hubspot Companies Export has gathered 13200 Companies
# Hubspot Companies Export has gathered 13300 Companies
# Hubspot Companies Export has gathered 13400 Companies
# Hubspot Companies Export has gathered 13500 Companies
# Hubspot Companies Export has gathered 13600 Companies
# Hubspot Companies Export has gathered 13700 Companies
# Hubspot Companies Export has gathered 13800 Companies
# Hubspot Companies Export has gathered 13900 Companies
# Hubspot Companies Export has gathered 14000 Companies
# Hubspot Companies Export has gathered 14100 Companies
# Hubspot Companies Export has gathered 14200 Companies
# Hubspot Companies Export has gathered 14300 Companies
# Hubspot Companies Export has gathered 14400 Companies
# Hubspot Companies Export has gathered 14500 Companies
# Hubspot Companies Export has gathered 14600 Companies
# Hubspot Companies Export has gathered 14700 Companies
# Hubspot Companies Export has gathered 14800 Companies
# Hubspot Companies Export has gathered 14900 Companies
# Hubspot Companies Export has gathered 15000 Companies
# Hubspot Companies Export has gathered 15100 Companies
# Hubspot Companies Export has gathered 15200 Companies
# Hubspot Companies Export has gathered 15300 Companies
# Hubspot Companies Export has gathered 15400 Companies
# Hubspot Companies Export has gathered 15500 Companies
# Hubspot Companies Export has gathered 15600 Companies
# Hubspot Companies Export has gathered 15700 Companies
# Hubspot Companies Export has gathered 15800 Companies
# Hubspot Companies Export has gathered 15900 Companies
# Hubspot Companies Export has gathered 16000 Companies
# Hubspot Companies Export has gathered 16100 Companies
# Hubspot Companies Export has gathered 16200 Companies
# Hubspot Companies Export has gathered 16300 Companies
# Hubspot Companies Export has gathered 16400 Companies
# Hubspot Companies Export has gathered 16500 Companies
# Hubspot Companies Export has gathered 16600 Companies
# Hubspot Companies Export has gathered 16700 Companies
# Hubspot Companies Export has gathered 16800 Companies
# Hubspot Companies Export has gathered 16900 Companies
# Hubspot Companies Export has gathered 17000 Companies
# Hubspot Companies Export has gathered 17100 Companies
# Hubspot Companies Export has gathered 17200 Companies
# Hubspot Companies Export has gathered 17300 Companies
# Hubspot Companies Export has gathered 17400 Companies
# Hubspot Companies Export has gathered 17500 Companies
# Hubspot Companies Export has gathered 17596 Companies
# La tabla hs_companies se actualizó correctamente en la base de datos.
# La tabla hs_companies_to_deals se actualizó correctamente en la base de datos.
# Hubspot Deals Export has gathered 100 Deals
# Hubspot Deals Export has gathered 200 Deals
# Hubspot Deals Export has gathered 300 Deals
# Hubspot Deals Export has gathered 400 Deals
# Hubspot Deals Export has gathered 500 Deals
# Hubspot Deals Export has gathered 600 Deals
# Hubspot Deals Export has gathered 700 Deals
# Hubspot Deals Export has gathered 800 Deals
# Hubspot Deals Export has gathered 900 Deals
# Hubspot Deals Export has gathered 1000 Deals
# Hubspot Deals Export has gathered 1100 Deals
# Hubspot Deals Export has gathered 1200 Deals
# Hubspot Deals Export has gathered 1300 Deals
# Hubspot Deals Export has gathered 1400 Deals
# Hubspot Deals Export has gathered 1500 Deals
# Hubspot Deals Export has gathered 1600 Deals
# Hubspot Deals Export has gathered 1700 Deals
# Hubspot Deals Export has gathered 1800 Deals
# Hubspot Deals Export has gathered 1900 Deals
# Hubspot Deals Export has gathered 2000 Deals
# Hubspot Deals Export has gathered 2100 Deals
# Hubspot Deals Export has gathered 2200 Deals
# Hubspot Deals Export has gathered 2300 Deals
# Hubspot Deals Export has gathered 2400 Deals
# Hubspot Deals Export has gathered 2500 Deals
# Hubspot Deals Export has gathered 2600 Deals
# Hubspot Deals Export has gathered 2700 Deals
# Hubspot Deals Export has gathered 2800 Deals
# Hubspot Deals Export has gathered 2900 Deals
# Hubspot Deals Export has gathered 3000 Deals
# Hubspot Deals Export has gathered 3100 Deals
# Hubspot Deals Export has gathered 3200 Deals
# Hubspot Deals Export has gathered 3300 Deals
# Hubspot Deals Export has gathered 3400 Deals
# Hubspot Deals Export has gathered 3500 Deals
# Hubspot Deals Export has gathered 3600 Deals
# Hubspot Deals Export has gathered 3632 Deals
# La tabla hs_deals se actualizó correctamente en la base de datos.
# Hubspot Contacts Export has gathered 58948 Contacts
# La tabla hs_contacts se actualizó correctamente en la base de datos.
# La tabla hs_contacts_to_deals se actualizó correctamente en la base de datos.
# La tabla hs_contacts_to_companies se actualizó correctamente en la base de datos.
# Hubspot Companies Export has gathered 17596 Companies
# La tabla hs_companies se actualizó correctamente en la base de datos.
# La tabla hs_companies_to_deals se actualizó correctamente en la base de datos.
# Hubspot Deals Export has gathered 3632 Deals
# La tabla hs_deals se actualizó correctamente en la base de datos.
